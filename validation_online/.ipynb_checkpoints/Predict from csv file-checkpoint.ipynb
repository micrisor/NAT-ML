# %%
# %load_ext autoreload
# %autoreload 2

# %%
import run_model

# %%
test_file = run_model.loadPaperValidationData()

# %%
feats = 'chemo'
pred, real = run_model.getPreds(feats, test_file)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(real,pred)
# Out:
# 0.8768796992481204

# %%
run_model.plotHistogram(test_file)
